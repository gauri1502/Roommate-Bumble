# %%
import numpy as np
import pandas as pd

# %%
budd = pd.read_excel('../Data/find_my_buddy.csv.xlsx', sheet_name='Buddy Sheet')

# %%
budd
# Out:
#                Full Name                 Email address  Gender     Hometown  \
# 0    Sachin Haldavanekar  sachinhaldavanekar@gmail.com    Male       Mumbai
# 1          Sanket Saurav             snkt087@gmail.com    Male        Patna
# 2             Viha Bidre           bidreviha@yahoo.com  Female   Davanagere
# 3        Sougata Dafader      sougatadafader@gmail.com    Male      Kolkata
# 4     Athul Muralidharan         athulmurali@gmail.com    Male      Chennai
# ..                   ...                           ...     ...          ...
# 518        Sanket Mathur          sanket0024@gmail.com    Male       Jaipur
# 519           Rohit Naik     rohit.naik.0708@gmail.com    Male  Navi Mumbai
# 520     Deepak Chandwani   deepakchandwani92@gmail.com    Male       Raipur
# 521             Nivedita         niveditac79@gmail.com  Female       Indore
# 522             Amandeep            ads71993@gmail.com    Male        Delhi
#
# ...
